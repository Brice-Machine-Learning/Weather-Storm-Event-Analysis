# %%
# Project: Storm Events Analysis (NOAA)
# Notebook: 04_feature_engineering.ipynb
# Goal: Determine and apply feature engineering techniques and characteristics.
# Author: Brice Nelson
# Date: XXXXXXX
